# %%
import numpy as np
import pandas as pd
import os

# %%
folder_path = 'C:/Users/chimi/Desktop/Python Data Science Projects/Cocoa Production/Pre-Processed Data'

# Get the list of CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Load the CSV files and save them as separate variables
for i, csv_file in enumerate(csv_files):
    file_path = os.path.join(folder_path, csv_file)
    variable_name = f'df{i+1}'
    globals()[variable_name] = pd.read_csv(file_path)

# Access the DataFrames using their respective variable names
print(df1.head())
print(df2.head())
print(df3.head())
# ... and so on
# Out:
# C:\Users\chimi\AppData\Local\Temp\ipykernel_10092\800784243.py:10: DtypeWarning: Columns (0,1,2,3,6,7,9,10,11,12,14,15,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   globals()[variable_name] = pd.read_csv(file_path)
#     Region  Year  Burn_Area(ha)  Tree_CoverExtent(Ha)      area__ha  \
# 0  Ashanti  2001   28756.227036          1.513515e+06  2.490413e+06
# 1  Ashanti  2002   18149.852344          1.513515e+06  2.490413e+06
# 2  Ashanti  2003   17397.065017          1.513515e+06  2.490413e+06
# 3  Ashanti  2004   21866.771643          1.513515e+06  2.490413e+06
# 4  Ashanti  2005   20638.045186          1.513515e+06  2.490413e+06
#
#    Avg_Tree_CoverGain(Ha)  Tree_CoverLoss(Ha)  TotalGreenHouse(mg)  \
# 0             1268.076744         5851.122804         2.100593e+06
# 1             1268.076744        15251.958338         5.537939e+06
# 2             1268.076744         8137.860448         2.952650e+06
# ...

# %%
df1.head(5)
# Out:
#     Region  Year  Burn_Area(ha)  Tree_CoverExtent(Ha)      area__ha  \
# 0  Ashanti  2001   28756.227036          1.513515e+06  2.490413e+06
# 1  Ashanti  2002   18149.852344          1.513515e+06  2.490413e+06
# 2  Ashanti  2003   17397.065017          1.513515e+06  2.490413e+06
# 3  Ashanti  2004   21866.771643          1.513515e+06  2.490413e+06
# 4  Ashanti  2005   20638.045186          1.513515e+06  2.490413e+06
#
#    Avg_Tree_CoverGain(Ha)  Tree_CoverLoss(Ha)  TotalGreenHouse(mg)  \
# 0             1268.076744         5851.122804         2.100593e+06
# 1             1268.076744        15251.958338         5.537939e+06
# 2             1268.076744         8137.860448         2.952650e+06
# 3             1268.076744         2014.371336         7.908153e+05
# 4             1268.076744         7549.778007         2.910321e+06
#
#    Tree_CoverLossFire(Ha)
# 0               25.217732
# 1               21.019157
# 2               14.290960
# 3                8.179280
# ...

# %%
df1['Region'].value_counts()
# Out:
# Ashanti        21
# Brong Ahafo    21
# Eastern        21
# Central        19
# Name: Region, dtype: int64

# %%
df1 = df1[df1['Year'] >= 2013].reset_index(drop=True)

# %%
df1
# Out:
#          Region  Year  Burn_Area(ha)  Tree_CoverExtent(Ha)      area__ha  \
# 0       Ashanti  2013   20831.035687          1.513515e+06  2.490413e+06
# 1       Ashanti  2014   16322.094905          1.513515e+06  2.490413e+06
# 2       Ashanti  2015   23471.854449          1.513515e+06  2.490413e+06
# 3       Ashanti  2016   21340.542707          1.513515e+06  2.490413e+06
# 4       Ashanti  2017   12811.426611          1.513515e+06  2.490413e+06
# 5       Ashanti  2018   20460.818438          1.513515e+06  2.490413e+06
# 6       Ashanti  2019   13088.187882          1.513515e+06  2.490413e+06
# 7       Ashanti  2020   26397.177007          1.513515e+06  2.490413e+06
# 8       Ashanti  2021   11178.615240          1.513515e+06  2.490413e+06
# 9   Brong Ahafo  2013   48813.287061          1.138942e+06  3.948867e+06
# 10  Brong Ahafo  2014   45856.234152          1.138942e+06  3.948867e+06
# 11  Brong Ahafo  2015   63881.483786          1.138942e+06  3.948867e+06
# ...

# %%
# DF 2 
# We only need 2013 to 2021 data
df2 = df2[df2['Year'] >= 2013].reset_index(drop=True)

# %%
df2 = df2.rename(columns={'Area harvested(ha)': 'National_Area harvested(ha)',
                        'Production(tonnes)': 'National_Production(tonnes)',
                        'Yield(hg/ha)': 'National_Yield(hg/ha)'})

# %%
df2
# Out:
#    Year  National_Area harvested(ha)  National_Production(tonnes)  \
# 0  2013                    1600300.0                     835466.0
# 1  2014                    1683765.0                     858720.0
# 2  2015                    1683765.0                     858720.0
# 3  2016                    1683765.0                     858720.0
# 4  2017                    1863830.0                     969300.0
# 5  2018                    1701251.0                     904700.0
# 6  2019                    1488374.0                     811700.0
# 7  2020                    1887726.0                    1047000.0
# 8  2021                    1457677.0                     822000.0
#
#    National_Yield(hg/ha)
# 0                 5221.0
# 1                 5100.0
# 2                 5100.0
# 3                 5100.0
# 4                 5201.0
# 5                 5318.0
# 6                 5454.0
# 7                 5546.0
# 8                 5639.0

# %%
df3 = df3[['NAME_1','elevation','x','y']]

# %%
# Dropping all values that have no elevation data
df3 = df3.dropna()

# %%
df3.rename(columns={'NAME_1':'Region','elevation':'Regional_Elevation'},inplace=True)

# %%
df3
# Out:
#           Region  Regional_Elevation         x          y
# 0        Ashanti                 290 -1.448573   6.803616
# 1    Brong Ahafo                 281 -1.657978   7.706088
# 2        Central                 290 -1.197226   5.560964
# 3        Eastern                 291 -0.450589   6.412757
# 4  Greater Accra                 287  0.065873   5.821748
# 5       Northern                 276 -0.966658   9.353757
# 6     Upper East                 274 -0.820531  10.777652
# 7     Upper West                 279 -2.209540  10.396060
# 8          Volta                 286  0.392035   7.269002
# 9        Western                 292 -2.415958   5.752793

# %%
# Filter in after 2013
df4 = df4[df4['Year'] >= 2013].reset_index(drop=True)

# %%
df4
# Out:
#   Country  Year  Agricultural land (% of land area)  \
# 0   Ghana  2013                           55.774651
# 1   Ghana  2014                           55.813756
# 2   Ghana  2015                           55.852861
# 3   Ghana  2016                           55.653336
# 4   Ghana  2017                           55.453810
# 5   Ghana  2018                           55.406258
# 6   Ghana  2019                           55.391316
# 7   Ghana  2020                           55.393020
#
#    Agricultural land (sq. km)  Arable land (% of land area)  \
# 0                   126909.64                     12.488354
# 1                   126998.62                     12.280039
# 2                   127087.60                     12.071724
# 3                   126633.60                     11.863409
# 4                   126179.60                     11.655094
# 5                   126071.40                     11.446779
# 6                   126037.40                     11.239343
# ...

# %%
# Dropping the country column
# Not needed for merge
df4.drop(columns=['Country'],inplace=True)

# %%
df4
# Out:
#    Year  Agricultural land (% of land area)  Agricultural land (sq. km)  \
# 0  2013                           55.774651                   126909.64
# 1  2014                           55.813756                   126998.62
# 2  2015                           55.852861                   127087.60
# 3  2016                           55.653336                   126633.60
# 4  2017                           55.453810                   126179.60
# 5  2018                           55.406258                   126071.40
# 6  2019                           55.391316                   126037.40
# 7  2020                           55.393020                   126037.40
#
#    Arable land (% of land area)  Arable land (hectares per person)  \
# 0                     12.488354                           0.103235
# 1                     12.280039                           0.099098
# 2                     12.071724                           0.095141
# ...

# %%
df5
# Out:
#            Region  Avg_Regional_pH  Avg_Regional_SOC  Avg_Regional_Fe_meq100g  \
# 0         Ashanti         5.241382          0.552780                 0.092114
# 1         Ashanti         5.241382          0.552780                 0.092114
# 2         Ashanti         5.241382          0.552780                 0.092114
# 3         Ashanti         5.241382          0.552780                 0.092114
# 4         Ashanti         5.241382          0.552780                 0.092114
# 5         Ashanti         5.241382          0.552780                 0.092114
# 6     Brong Ahafo         5.937407          0.613370                 0.051407
# 7     Brong Ahafo         5.937407          0.613370                 0.051407
# 8     Brong Ahafo         5.937407          0.613370                 0.051407
# 9     Brong Ahafo         5.937407          0.613370                 0.051407
# 10    Brong Ahafo         5.937407          0.613370                 0.051407
# ...

# %%
df6
# Out:
#         Year       Region  AnnualForecastedDryDays Country_x  \
# 0       2015  Brong Ahafo                    36.80     Ghana
# 1       2015  Brong Ahafo                    36.80     Ghana
# 2       2015  Brong Ahafo                    36.80     Ghana
# 3       2015  Brong Ahafo                    36.80     Ghana
# 4       2015  Brong Ahafo                    36.80     Ghana
# ...      ...          ...                      ...       ...
# 111451  2100      Western                    34.23     Ghana
# 111452  2100      Western                    34.23     Ghana
# 111453  2100      Western                    34.23     Ghana
# 111454  2100      Western                    34.23     Ghana
# 111455  2100      Western                    34.23     Ghana
#
#         AnnualForecastedDrought(SPEI Index) Country_y  \
# 0                                       0.0     Ghana
# 1                                       0.0     Ghana
# 2                                       0.0     Ghana
# ...

# %%
df6.columns
# Out:
# Index(['Year', 'Region', 'AnnualForecastedDryDays', 'Country_x',
#        'AnnualForecastedDrought(SPEI Index)', 'Country_y',
#        'Annualmaxdailytempforecast', 'Country_x.1', 'Annualmeantempforecast',
#        'Country_y.1', 'Annualmindailytempforecast', 'Country',
#        'AnnualWetDaysForecast', 'Month_x', 'MonthlyWetDaysForecast',
#        'AnnualForecastedPrecip(mm)', 'AnnualRelativeHumidityForecast',
#        'Month_y', 'MonthlyReleativeHumidityForecast'],
#       dtype='object')

# %%
# Looks like we have to drop some duplicate columns
df6.drop(columns=['Country_y','Country_y.1','Country_x.1','Country_x','Month_y'],inplace=True)

# %%
df6.rename(columns={'Month_x':'Month'},inplace=True)

# %%
df6.rename(columns={'Year':'Forecast_Year'},inplace=True)

# %%
df6= df6[(df6['Forecast_Year'] >= 2024) & (df6['Forecast_Year'] <= 2034)].reset_index(drop=True)

# %%
df6 = df6.groupby(['Region','Forecast_Year']).mean().reset_index()
# Out:
# C:\Users\chimi\AppData\Local\Temp\ipykernel_10092\2785152739.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df6 = df6.groupby(['Region','Forecast_Year']).mean().reset_index()

# %%
df6.head(5)
# Out:
#         Region  Forecast_Year  AnnualForecastedDryDays  \
# 0  Brong Ahafo           2024                    51.56
# 1  Brong Ahafo           2025                    56.13
# 2  Brong Ahafo           2026                    56.12
# 3  Brong Ahafo           2027                    63.23
# 4  Brong Ahafo           2028                    42.06
#
#    AnnualForecastedDrought(SPEI Index)  Annualmaxdailytempforecast  \
# 0                                  0.0                       39.75
# 1                                  0.0                       39.60
# 2                                  0.0                       39.39
# 3                                  0.0                       39.43
# 4                                  0.0                       39.80
#
#    Annualmeantempforecast  Annualmindailytempforecast  AnnualWetDaysForecast  \
# 0                   27.86                       15.96                 117.61
# ...

# %%
df6.columns
# Out:
# Index(['Region', 'Forecast_Year', 'AnnualForecastedDryDays',
#        'AnnualForecastedDrought(SPEI Index)', 'Annualmaxdailytempforecast',
#        'Annualmeantempforecast', 'Annualmindailytempforecast',
#        'AnnualWetDaysForecast', 'MonthlyWetDaysForecast',
#        'AnnualForecastedPrecip(mm)', 'AnnualRelativeHumidityForecast',
#        'MonthlyReleativeHumidityForecast'],
#       dtype='object')

# %%
df7
# Out:
#     Year   Region  AnnualMeanTemp Country_x  AnnualPrecip Country_y
# 0   2013  Ashanti           26.99     Ghana       1208.32     Ghana
# 1   2014  Ashanti           27.10     Ghana       1341.62     Ghana
# 2   2015  Ashanti           27.28     Ghana       1220.58     Ghana
# 3   2016  Ashanti           27.56     Ghana       1289.41     Ghana
# 4   2017  Ashanti           27.38     Ghana       1296.80     Ghana
# ..   ...      ...             ...       ...           ...       ...
# 85  2017  Western           27.33     Ghana       1584.60     Ghana
# 86  2018  Western           27.16     Ghana       1668.96     Ghana
# 87  2019  Western           27.04     Ghana       1663.42     Ghana
# 88  2020  Western           27.31     Ghana       1524.82     Ghana
# 89  2021  Western           27.42     Ghana       1622.00     Ghana
#
# [90 rows x 6 columns]

# %%
# Can drop the country Column
df7.drop(columns=['Country_x','Country_y'],inplace=True)

# %%
df7['Region'].value_counts()
# Out:
# Ashanti          9
# Brong Ahafo      9
# Central          9
# Eastern          9
# Greater Accra    9
# Northern         9
# Upper East       9
# Upper West       9
# Volta            9
# Western          9
# Name: Region, dtype: int64

# %%
# Ghana weather dataset to merge with the preprocessed files
df8['Region'].value_counts()
# Out:
# Ghana    19030
# Name: Region, dtype: int64

# %%
# Merge all regional files together
concatenated_df = pd.concat([df8,df5,df3,df1,df7],axis=1)

# %%
concatenated_df['Region'].drop_duplicates()
# Out:
#    Region         Region         Region       Region         Region
# 0   Ghana        Ashanti        Ashanti      Ashanti        Ashanti
# 1   Ghana        Ashanti    Brong Ahafo      Ashanti        Ashanti
# 2   Ghana        Ashanti        Central      Ashanti        Ashanti
# 3   Ghana        Ashanti        Eastern      Ashanti        Ashanti
# 4   Ghana        Ashanti  Greater Accra      Ashanti        Ashanti
# 5   Ghana        Ashanti       Northern      Ashanti        Ashanti
# 6   Ghana    Brong Ahafo     Upper East      Ashanti        Ashanti
# 7   Ghana    Brong Ahafo     Upper West      Ashanti        Ashanti
# 8   Ghana    Brong Ahafo          Volta      Ashanti        Ashanti
# 9   Ghana    Brong Ahafo        Western  Brong Ahafo    Brong Ahafo
# 10  Ghana    Brong Ahafo            NaN  Brong Ahafo    Brong Ahafo
# 12  Ghana        Central            NaN  Brong Ahafo    Brong Ahafo
# 18  Ghana        Eastern            NaN      Central        Central
# ...

# %%
# Filter the regions we have daily weather dataset on
regions = ['Ashanti', 'Western', 'Eastern', 'Volta', 'Central']
filtered_df = concatenated_df[concatenated_df['Region'].isin(regions)]

# %%
concatenated_df.head(5)
# Out:
#    Country Region   datetime  tempmax  tempmin  temp   dew  humidity  precip  \
# 0  Ashanti  Ghana 2013-01-01     30.3     16.6  23.6  15.9      64.8     0.0
# 1  Ashanti  Ghana 2013-01-02     32.4     16.6  24.1  13.2      54.9     0.0
# 2  Ashanti  Ghana 2013-01-03     30.5     19.7  25.0  16.8      62.8     0.0
# 3  Ashanti  Ghana 2013-01-04     29.2     18.9  22.8  16.2      67.9     0.0
# 4  Ashanti  Ghana 2013-01-05     32.4     17.5  24.1  13.7      57.1     0.0
#
#    windspeed  ...  Year  Burn_Area(ha)  Tree_CoverExtent(Ha)      area__ha  \
# 0       25.2  ...  2013   20831.035687          1.513515e+06  2.490413e+06
# 1       18.7  ...  2013   16322.094905          1.513515e+06  2.490413e+06
# 2        9.4  ...  2013   23471.854449          1.513515e+06  2.490413e+06
# 3       12.6  ...  2013   21340.542707          1.513515e+06  2.490413e+06
# 4       16.2  ...  2013   12811.426611          1.513515e+06  2.490413e+06
#
# ...

# %%
# Extract year columns from datetime 
concatenated_df['datetime'] = pd.to_datetime(concatenated_df['datetime'])
concatenated_df['Year'] = concatenated_df['datetime'].dt.year
# Out:
# C:\Users\chimi\AppData\Local\Temp\ipykernel_10092\2525587547.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   concatenated_df['datetime'] = pd.to_datetime(concatenated_df['datetime'])
# C:\Users\chimi\AppData\Local\Temp\ipykernel_10092\2525587547.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   concatenated_df['Year'] = concatenated_df['datetime'].dt.year

# %%
# Drop the duplicate "Region" columns
concatenated_df = concatenated_df.loc[:,~concatenated_df.columns.duplicated()]

# %%
# Check rows of df1
concatenated_df['Year'] = concatenated_df['Year'].astype(int)

# %%
# Merge on Year columns
concatenated_df = concatenated_df.merge(df2, on=['Year'])

# %%
# Final Merge
final_df = concatenated_df.merge(df4, on=['Year'])

# %%
final_df.to_csv('merged_final.csv',index=False)
