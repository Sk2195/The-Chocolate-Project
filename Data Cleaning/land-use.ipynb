# %%
import pandas as pd
import numpy as np
import os

# %%
folder_path = r"C:\Users\chimi\Desktop\Python Data Science Projects\Cocoa Production\Land Usage"

# Get all the CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith(".csv")]

# Create a dictionary to store the dataframes
dataframes = {}

# Read each CSV file and store it in the dictionary
for i, file in enumerate(csv_files):
    file_path = os.path.join(folder_path, file)
    df_name = f"df{i+1}"
    dataframes[df_name] = pd.read_csv(file_path)

# To access each dataframe use its corresponding variable name (e.g., df1, df2, etc.)
# For example, you can print the first few rows of df1
print(dataframes["df1"].head())

# Access each dataframe in the dictionary and save it separately in its own variable
for i, df_name in enumerate(dataframes):
    globals()[f"df{i+1}"] = dataframes[df_name]

# Access each dataframe using its corresponding variable name (e.g., df1, df2, etc.)
# For example, you can print the first few rows of df1
print(df1.head())
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                        Indicator Name  Indicator Code  1960       1961  \
# 0  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  11.111111
# 1  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  42.345505
# 2  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  57.801696
# 3  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  32.945755
# 4  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  36.237443
#
#         1962       1963       1964       1965  ...       2013       2014  \
# 0  11.111111  11.111111  11.111111  11.111111  ...  11.111111  11.111111
# 1  42.329995  42.366298  42.348112  42.330887  ...  43.524271  43.674175
# ...

# %%
# Filter data by Country:Ghana
df1 = df1[df1['Country Name'] == 'Ghana']

# %%
df1.head(5)
# Out:
#    Country Name Country Code                      Indicator Name  \
# 83        Ghana          GHA  Agricultural land (% of land area)
#
#     Indicator Code  1960       1961       1962       1963       1964  \
# 83  AG.LND.AGRI.ZS   NaN  51.419531  51.419531  51.419531  51.419531
#
#          1965  ...       2013       2014       2015       2016      2017  \
# 83  51.419531  ...  55.774651  55.813756  55.852861  55.653336  55.45381
#
#          2018       2019      2020  2021  2022
# 83  55.406258  55.391316  55.39302   NaN   NaN
#
# [1 rows x 67 columns]

# %%
df1.drop(columns=['Country Code', 'Indicator Code'], inplace=True)
# Out:
# C:\Users\chimi\AppData\Local\Temp\ipykernel_14740\2431779735.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(columns=['Country Code', 'Indicator Code'], inplace=True)

# %%
df1.head(5)
# Out:
#    Country Name                      Indicator Name  1960       1961  \
# 83        Ghana  Agricultural land (% of land area)   NaN  51.419531
#
#          1962       1963       1964       1965       1966       1967  ...  \
# 83  51.419531  51.419531  51.419531  51.419531  51.419531  51.419531  ...
#
#          2013       2014       2015       2016      2017       2018  \
# 83  55.774651  55.813756  55.852861  55.653336  55.45381  55.406258
#
#          2019      2020  2021  2022
# 83  55.391316  55.39302   NaN   NaN
#
# [1 rows x 65 columns]

# %%
# Melt the dataset
df1 = df1.melt(id_vars=['Country Name','Indicator Name'],var_name='Year',value_name='Agricultural land (% of land area')

# %%
df1.head(5)
# Out:
#   Country Name                      Indicator Name  Year  \
# 0        Ghana  Agricultural land (% of land area)  1960
# 1        Ghana  Agricultural land (% of land area)  1961
# 2        Ghana  Agricultural land (% of land area)  1962
# 3        Ghana  Agricultural land (% of land area)  1963
# 4        Ghana  Agricultural land (% of land area)  1964
#
#    Agricultural land (% of land area
# 0                                NaN
# 1                          51.419531
# 2                          51.419531
# 3                          51.419531
# 4                          51.419531

# %%
df1.drop(columns=['Indicator Name'],inplace=True)

# %%
df1.head(5)
# Out:
#   Country Name  Year  Agricultural land (% of land area
# 0        Ghana  1960                                NaN
# 1        Ghana  1961                          51.419531
# 2        Ghana  1962                          51.419531
# 3        Ghana  1963                          51.419531
# 4        Ghana  1964                          51.419531

# %%
df2.head(5)
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  Arable land (% of land area)
# 1  Africa Eastern and Southern          AFE  Arable land (% of land area)
# 2                  Afghanistan          AFG  Arable land (% of land area)
# 3   Africa Western and Central          AFW  Arable land (% of land area)
# 4                       Angola          AGO  Arable land (% of land area)
#
#    Indicator Code  1960       1961       1962       1963       1964  \
# 0  AG.LND.ARBL.ZS   NaN  11.111111  11.111111  11.111111  11.111111
# 1  AG.LND.ARBL.ZS   NaN   4.702843   4.754588   4.866723   4.918674
# 2  AG.LND.ARBL.ZS   NaN  11.728991  11.805651  11.882311  11.958972
# 3  AG.LND.ARBL.ZS   NaN   6.984022   7.076486   7.331711   7.445694
# 4  AG.LND.ARBL.ZS   NaN   2.141654   2.165717   2.181760   2.205823
#
#         1965  ...       2013       2014       2015       2016       2017  \
# ...

# %%
df2 = df2[df2['Country Name'] == 'Ghana']

# %%
df2.head(5)
# Out:
#    Country Name Country Code                Indicator Name  Indicator Code  \
# 83        Ghana          GHA  Arable land (% of land area)  AG.LND.ARBL.ZS
#
#     1960      1961      1962      1963      1964      1965  ...       2013  \
# 83   NaN  7.471214  7.471214  7.471214  7.471214  7.471214  ...  12.488354
#
#          2014       2015       2016       2017       2018       2019  \
# 83  12.280039  12.071724  11.863409  11.655094  11.446779  11.239343
#
#         2020  2021  2022
# 83  11.04631   NaN   NaN
#
# [1 rows x 67 columns]

# %%
df2.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)
# Out:
# C:\Users\chimi\AppData\Local\Temp\ipykernel_14740\377004924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)

# %%
df2.head(5)
# Out:
#    Country Name  1960      1961      1962      1963      1964      1965  \
# 83        Ghana   NaN  7.471214  7.471214  7.471214  7.471214  7.471214
#
#         1966      1967      1968  ...       2013       2014       2015  \
# 83  7.471214  7.471214  7.471214  ...  12.488354  12.280039  12.071724
#
#          2016       2017       2018       2019      2020  2021  2022
# 83  11.863409  11.655094  11.446779  11.239343  11.04631   NaN   NaN
#
# [1 rows x 64 columns]

# %%
df2 = df2.melt(id_vars=['Country Name'],var_name='Year',value_name='Arable land (% land area)')

# %%
df2.head(5)
# Out:
#   Country Name  Year  Arable land (% land area)
# 0        Ghana  1960                        NaN
# 1        Ghana  1961                   7.471214
# 2        Ghana  1962                   7.471214
# 3        Ghana  1963                   7.471214
# 4        Ghana  1964                   7.471214

# %%
df3
# Out:
#                     Country Name Country Code      Indicator Name  \
# 0                          Aruba          ABW  Land area (sq. km)
# 1    Africa Eastern and Southern          AFE  Land area (sq. km)
# 2                    Afghanistan          AFG  Land area (sq. km)
# 3     Africa Western and Central          AFW  Land area (sq. km)
# 4                         Angola          AGO  Land area (sq. km)
# ..                           ...          ...                 ...
# 261                       Kosovo          XKX  Land area (sq. km)
# 262                  Yemen, Rep.          YEM  Land area (sq. km)
# 263                 South Africa          ZAF  Land area (sq. km)
# 264                       Zambia          ZMB  Land area (sq. km)
# 265                     Zimbabwe          ZWE  Land area (sq. km)
#
#      Indicator Code  1960        1961        1962        1963        1964  \
# 0    AG.LND.TOTL.K2   NaN       180.0       180.0       180.0       180.0
# ...

# %%
df3 = df3[df3['Country Name'] == 'Ghana']

# %%
df3.head()
# Out:
#    Country Name Country Code      Indicator Name  Indicator Code  1960  \
# 83        Ghana          GHA  Land area (sq. km)  AG.LND.TOTL.K2   NaN
#
#         1961      1962      1963      1964      1965  ...      2013      2014  \
# 83  227540.0  227540.0  227540.0  227540.0  227540.0  ...  227540.0  227540.0
#
#         2015      2016      2017      2018      2019      2020  2021  2022
# 83  227540.0  227540.0  227540.0  227540.0  227540.0  227533.0   NaN   NaN
#
# [1 rows x 67 columns]

# %%
df3.drop(columns=['Country Code', 'Indicator Name','Indicator Code'],inplace=True)
# Out:
# C:\Users\chimi\AppData\Local\Temp\ipykernel_14740\2837043831.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop(columns=['Country Code', 'Indicator Name','Indicator Code'],inplace=True)

# %%
df3 = df3.melt(id_vars=['Country Name'], var_name='Year', value_name='Land Area (sq. km)')

# %%
# Assuming you have the dataframes df1, df2, and df3

# Merge df1 and df2 based on 'Country Name' and 'Year'
merged_df = pd.merge(df1, df2, on=['Country Name', 'Year'])

# Merge merged_df and df3 based on 'Country Name' and 'Year'
final_df = pd.merge(merged_df, df3, on=['Country Name', 'Year'])

# Print the final merged dataframe
print(final_df)
# Out:
#    Country Name  Year  Agricultural land (% of land area  \
# 0         Ghana  1960                                NaN
# 1         Ghana  1961                          51.419531
# 2         Ghana  1962                          51.419531
# 3         Ghana  1963                          51.419531
# 4         Ghana  1964                          51.419531
# ..          ...   ...                                ...
# 58        Ghana  2018                          55.406258
# 59        Ghana  2019                          55.391316
# 60        Ghana  2020                          55.393020
# 61        Ghana  2021                                NaN
# 62        Ghana  2022                                NaN
#
#     Arable land (% land area)  Land Area (sq. km)
# 0                         NaN                 NaN
# 1                    7.471214            227540.0
# 2                    7.471214            227540.0
# 3                    7.471214            227540.0
# ...

# %%
final_df.dtypes
# Out:
# Country Name                          object
# Year                                  object
# Agricultural land (% of land area    float64
# Arable land (% land area)            float64
# Land Area (sq. km)                   float64
# dtype: object

# %%
final_df['Year'] = final_df['Year'].astype('int64')

# %%
final_df.head(5)
# Out:
#   Country Name  Year  Agricultural land (% of land area  \
# 0        Ghana  1960                                NaN
# 1        Ghana  1961                          51.419531
# 2        Ghana  1962                          51.419531
# 3        Ghana  1963                          51.419531
# 4        Ghana  1964                          51.419531
#
#    Arable land (% land area)  Land Area (sq. km)
# 0                        NaN                 NaN
# 1                   7.471214            227540.0
# 2                   7.471214            227540.0
# 3                   7.471214            227540.0
# 4                   7.471214            227540.0

# %%
# Read Forest data profile
file_path = r"C:\Users\chimi\Desktop\Python Data Science Projects\Cocoa Production\Data Collection\Forest Area(%Land Area.csv"
data = pd.read_csv(file_path)

# Now you can work with the data
# For example, you can print the first few rows
print(data.head())
# Out:
#    Year  Forest area (% of land area)
# 0  1990                         43.62
# 1  1991                         43.14
# 2  1992                         42.67
# 3  1993                         42.20
# 4  1994                         41.72

# %%
final_df.dtypes
# Out:
# Country Name                          object
# Year                                   int64
# Agricultural land (% of land area    float64
# Arable land (% land area)            float64
# Land Area (sq. km)                   float64
# dtype: object

# %%
# Merge the datasets on 'Year'
final_df = pd.merge(final_df, data, on='Year')

# %%
final_df.head(5)
# Out:
#   Country Name  Year  Agricultural land (% of land area  \
# 0        Ghana  1990                          55.396853
# 1        Ghana  1991                          55.902259
# 2        Ghana  1992                          55.902259
# 3        Ghana  1993                          56.253845
# 4        Ghana  1994                          56.693329
#
#    Arable land (% land area)  Land Area (sq. km)  Forest area (% of land area)
# 0                  11.866046            227540.0                         43.62
# 1                  12.305529            227540.0                         43.14
# 2                  12.305529            227540.0                         42.67
# 3                  12.305529            227540.0                         42.20
# 4                  12.305529            227540.0                         41.72

# %%
final_df.to_csv('land_use.csv',index=False)
