# %%
import pandas as pd
import numpy as np
import os

# %%
folder_path = r"C:\Users\chimi\Desktop\Python Data Science Projects\Cocoa Production\Land Usage"

# Get all the CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith(".csv")]

# Create a dictionary to store the dataframes
dataframes = {}

# Read each CSV file and store it in the dictionary
for i, file in enumerate(csv_files):
    file_path = os.path.join(folder_path, file)
    df_name = f"df{i+1}"
    dataframes[df_name] = pd.read_csv(file_path)

# To access each dataframe use its corresponding variable name (e.g., df1, df2, etc.)
# For example, you can print the first few rows of df1
print(dataframes["df1"].head())

# Access each dataframe in the dictionary and save it separately in its own variable
for i, df_name in enumerate(dataframes):
    globals()[f"df{i+1}"] = dataframes[df_name]

# Access each dataframe using its corresponding variable name (e.g., df1, df2, etc.)
# For example, you can print the first few rows of df1
print(df1.head())
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS   NaN
# 1  Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS   NaN
# 2  Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS   NaN
# 3  Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS   NaN
# 4  Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...      2013      2014      2015     2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...       NaN       NaN       NaN      NaN
# ...

# %%
# Filter data by Country:Ghana
df1 = df1[df1['Country Name'] == 'Ghana']

# %%
df1.head(5)
# Out:
#    Country Name Country Code  \
# 83        Ghana          GHA
#
#                                        Indicator Name     Indicator Code  \
# 83  Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
#
#     1960  1961  1962  1963  1964  1965  ...      2013      2014  2015  2016  \
# 83   NaN   NaN   NaN   NaN   NaN   NaN  ...  0.220629  0.283468   NaN   NaN
#
#     2017  2018  2019  2020  2021  2022
# 83   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 67 columns]

# %%
df1.drop(columns=['Country Code', 'Indicator Code'], inplace=True)
# Out:
# C:\Users\chimi\AppData\Local\Temp\ipykernel_4256\2431779735.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(columns=['Country Code', 'Indicator Code'], inplace=True)

# %%
# Melt the dataset
df1 = df1.melt(id_vars=['Country Name','Indicator Name'],var_name='Year',value_name='Agricultural irrigated land (% of total agriculture)')

# %%
df1.head(5)
# Out:
#   Country Name                                     Indicator Name  Year  \
# 0        Ghana  Agricultural irrigated land (% of total agricu...  1960
# 1        Ghana  Agricultural irrigated land (% of total agricu...  1961
# 2        Ghana  Agricultural irrigated land (% of total agricu...  1962
# 3        Ghana  Agricultural irrigated land (% of total agricu...  1963
# 4        Ghana  Agricultural irrigated land (% of total agricu...  1964
#
#    Agricultural irrigated land (% of total agriculture)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df1.drop(columns=['Indicator Name'],inplace=True)

# %%
df1.head(5)
# Out:
#   Country Name  Year  Agricultural irrigated land (% of total agriculture)
# 0        Ghana  1960                                                NaN
# 1        Ghana  1961                                                NaN
# 2        Ghana  1962                                                NaN
# 3        Ghana  1963                                                NaN
# 4        Ghana  1964                                                NaN

# %%
df1.rename(columns={'Country Name':'Country'},inplace=True)

# %%
df1.head(5)
# Out:
#   Country  Year  Agricultural irrigated land (% of total agriculture)
# 0   Ghana  1960                                                NaN
# 1   Ghana  1961                                                NaN
# 2   Ghana  1962                                                NaN
# 3   Ghana  1963                                                NaN
# 4   Ghana  1964                                                NaN

# %%
df2.head(5)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                        Indicator Name  Indicator Code  1960       1961  \
# 0  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  11.111111
# 1  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  42.345505
# 2  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  57.801696
# 3  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  32.945755
# 4  Agricultural land (% of land area)  AG.LND.AGRI.ZS   NaN  36.237443
#
#         1962       1963       1964       1965  ...       2013       2014  \
# 0  11.111111  11.111111  11.111111  11.111111  ...  11.111111  11.111111
# 1  42.329995  42.366298  42.348112  42.330887  ...  43.524271  43.674175
# ...

# %%
df2.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
df2 = df2[df2['Country Name'] == 'Ghana']

# %%
df2.head(5)
# Out:
#    Country Name Country Code                      Indicator Name  \
# 83        Ghana          GHA  Agricultural land (% of land area)
#
#     Indicator Code  1960       1961       1962       1963       1964  \
# 83  AG.LND.AGRI.ZS   NaN  51.419531  51.419531  51.419531  51.419531
#
#          1965  ...       2013       2014       2015       2016      2017  \
# 83  51.419531  ...  55.774651  55.813756  55.852861  55.653336  55.45381
#
#          2018       2019      2020  2021  2022
# 83  55.406258  55.391316  55.39302   NaN   NaN
#
# [1 rows x 67 columns]

# %%
df2.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)
# Out:
# C:\Users\chimi\AppData\Local\Temp\ipykernel_4256\377004924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)

# %%
df2.head(5)
# Out:
#    Country Name  1960       1961       1962       1963       1964       1965  \
# 83        Ghana   NaN  51.419531  51.419531  51.419531  51.419531  51.419531
#
#          1966       1967       1968  ...       2013       2014       2015  \
# 83  51.419531  51.419531  51.419531  ...  55.774651  55.813756  55.852861
#
#          2016      2017       2018       2019      2020  2021  2022
# 83  55.653336  55.45381  55.406258  55.391316  55.39302   NaN   NaN
#
# [1 rows x 64 columns]

# %%
df2 = df2.melt(id_vars=['Country Name'],var_name='Year',value_name='Agricultural land (% of land area)')

# %%
df2.head(5)
# Out:
#   Country Name  Year  Agricultural land (% of land area)
# 0        Ghana  1960                                 NaN
# 1        Ghana  1961                           51.419531
# 2        Ghana  1962                           51.419531
# 3        Ghana  1963                           51.419531
# 4        Ghana  1964                           51.419531

# %%
df2.rename(columns={'Country Name': 'Country'}, inplace=True)

# %%
df2.head(5)
# Out:
#   Country  Year  Agricultural land (% of land area)
# 0   Ghana  1960                                 NaN
# 1   Ghana  1961                           51.419531
# 2   Ghana  1962                           51.419531
# 3   Ghana  1963                           51.419531
# 4   Ghana  1964                           51.419531

# %%
df3
# Out:
#                     Country Name Country Code              Indicator Name  \
# 0                          Aruba          ABW  Agricultural land (sq. km)
# 1    Africa Eastern and Southern          AFE  Agricultural land (sq. km)
# 2                    Afghanistan          AFG  Agricultural land (sq. km)
# 3     Africa Western and Central          AFW  Agricultural land (sq. km)
# 4                         Angola          AGO  Agricultural land (sq. km)
# ..                           ...          ...                         ...
# 261                       Kosovo          XKX  Agricultural land (sq. km)
# 262                  Yemen, Rep.          YEM  Agricultural land (sq. km)
# 263                 South Africa          ZAF  Agricultural land (sq. km)
# 264                       Zambia          ZMB  Agricultural land (sq. km)
# 265                     Zimbabwe          ZWE  Agricultural land (sq. km)
#
#      Indicator Code  1960       1961       1962       1963       1964  \
# ...

# %%
df3 = df3[df3['Country Name'] == 'Ghana']

# %%
df3.head()
# Out:
#    Country Name Country Code              Indicator Name  Indicator Code  \
# 83        Ghana          GHA  Agricultural land (sq. km)  AG.LND.AGRI.K2
#
#     1960      1961      1962      1963      1964      1965  ...       2013  \
# 83   NaN  117000.0  117000.0  117000.0  117000.0  117000.0  ...  126909.64
#
#          2014      2015      2016      2017      2018      2019      2020  \
# 83  126998.62  127087.6  126633.6  126179.6  126071.4  126037.4  126037.4
#
#     2021  2022
# 83   NaN   NaN
#
# [1 rows x 67 columns]

# %%
df3.drop(columns=['Country Code', 'Indicator Name','Indicator Code'],inplace=True)
# Out:
# C:\Users\chimi\AppData\Local\Temp\ipykernel_4256\2837043831.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop(columns=['Country Code', 'Indicator Name','Indicator Code'],inplace=True)

# %%
df3 = df3.melt(id_vars=['Country Name'], var_name='Year', value_name='Agricultural land (sq. km)')

# %%
df3.head(5)
# Out:
#   Country Name  Year  Agricultural land (sq. km)
# 0        Ghana  1960                         NaN
# 1        Ghana  1961                    117000.0
# 2        Ghana  1962                    117000.0
# 3        Ghana  1963                    117000.0
# 4        Ghana  1964                    117000.0

# %%
df3.rename(columns={'Country Name':'Country'},inplace=True)

# %%
df3.head(5)
# Out:
#   Country  Year  Agricultural land (sq. km)
# 0   Ghana  1960                         NaN
# 1   Ghana  1961                    117000.0
# 2   Ghana  1962                    117000.0
# 3   Ghana  1963                    117000.0
# 4   Ghana  1964                    117000.0

# %%
df4.head(5)
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  Arable land (% of land area)
# 1  Africa Eastern and Southern          AFE  Arable land (% of land area)
# 2                  Afghanistan          AFG  Arable land (% of land area)
# 3   Africa Western and Central          AFW  Arable land (% of land area)
# 4                       Angola          AGO  Arable land (% of land area)
#
#    Indicator Code  1960       1961       1962       1963       1964  \
# 0  AG.LND.ARBL.ZS   NaN  11.111111  11.111111  11.111111  11.111111
# 1  AG.LND.ARBL.ZS   NaN   4.702843   4.754588   4.866723   4.918674
# 2  AG.LND.ARBL.ZS   NaN  11.728991  11.805651  11.882311  11.958972
# 3  AG.LND.ARBL.ZS   NaN   6.984022   7.076486   7.331711   7.445694
# 4  AG.LND.ARBL.ZS   NaN   2.141654   2.165717   2.181760   2.205823
#
#         1965  ...       2013       2014       2015       2016       2017  \
# ...

# %%
df4 = df4[df4['Country Name'] == 'Ghana']

# %%
df4.drop(columns=['Country Code','Indicator Code','Indicator Name'],inplace=True)
# Out:
# C:\Users\chimi\AppData\Local\Temp\ipykernel_4256\816892037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4.drop(columns=['Country Code','Indicator Code','Indicator Name'],inplace=True)

# %%
df4 = df4.melt(id_vars=['Country Name'],var_name='Year', value_name='Arable land (% of land area)')

# %%
df4.head(5)
# Out:
#   Country Name  Year  Arable land (% of land area)
# 0        Ghana  1960                           NaN
# 1        Ghana  1961                      7.471214
# 2        Ghana  1962                      7.471214
# 3        Ghana  1963                      7.471214
# 4        Ghana  1964                      7.471214

# %%
df4.rename(columns={'Country Name':'Country'},inplace=True)

# %%
df4.head(5)
# Out:
#   Country  Year  Arable land (% of land area)
# 0   Ghana  1960                           NaN
# 1   Ghana  1961                      7.471214
# 2   Ghana  1962                      7.471214
# 3   Ghana  1963                      7.471214
# 4   Ghana  1964                      7.471214

# %%
df5 = df5[df5['Country Name'] == 'Ghana' ]

# %%
df5
# Out:
#    Country Name Country Code                     Indicator Name  \
# 83        Ghana          GHA  Arable land (hectares per person)
#
#        Indicator Code  1960      1961      1962      1963      1964      1965  \
# 83  AG.LND.ARBL.HA.PC   NaN  0.239133  0.233478  0.227936  0.222507  0.217177
#
#     ...      2013      2014      2015      2016     2017      2018     2019  \
# 83  ...  0.103235  0.099098  0.095141  0.091337  0.08775  0.084371  0.08113
#
#         2020  2021  2022
# 83  0.078103   NaN   NaN
#
# [1 rows x 67 columns]

# %%
df5.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)
# Out:
# C:\Users\chimi\AppData\Local\Temp\ipykernel_4256\2498843451.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)

# %%
df5 = df5.melt(id_vars='Country Name',var_name='Year',value_name='Arable land (hectares per person)')

# %%
df5.head(5)
# Out:
#   Country Name  Year  Arable land (hectares per person)
# 0        Ghana  1960                                NaN
# 1        Ghana  1961                           0.239133
# 2        Ghana  1962                           0.233478
# 3        Ghana  1963                           0.227936
# 4        Ghana  1964                           0.222507

# %%
df5.rename(columns={'Country Name':'Country'},inplace=True)

# %%
df5.head(5)
# Out:
#   Country  Year  Arable land (hectares per person)
# 0   Ghana  1960                                NaN
# 1   Ghana  1961                           0.239133
# 2   Ghana  1962                           0.233478
# 3   Ghana  1963                           0.227936
# 4   Ghana  1964                           0.222507

# %%
df6 = df6[df6['Country Name'] == 'Ghana']

# %%
df6
# Out:
#    Country Name Country Code      Indicator Name  Indicator Code  1960  \
# 83        Ghana          GHA  Land area (sq. km)  AG.LND.TOTL.K2   NaN
#
#         1961      1962      1963      1964      1965  ...      2013      2014  \
# 83  227540.0  227540.0  227540.0  227540.0  227540.0  ...  227540.0  227540.0
#
#         2015      2016      2017      2018      2019      2020  2021  2022
# 83  227540.0  227540.0  227540.0  227540.0  227540.0  227533.0   NaN   NaN
#
# [1 rows x 67 columns]

# %%
df6.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)
# Out:
# C:\Users\chimi\AppData\Local\Temp\ipykernel_4256\1257553091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6.drop(columns=['Country Code','Indicator Name','Indicator Code'],inplace=True)

# %%
df6
# Out:
#    Country Name  1960      1961      1962      1963      1964      1965  \
# 83        Ghana   NaN  227540.0  227540.0  227540.0  227540.0  227540.0
#
#         1966      1967      1968  ...      2013      2014      2015      2016  \
# 83  227540.0  227540.0  227540.0  ...  227540.0  227540.0  227540.0  227540.0
#
#         2017      2018      2019      2020  2021  2022
# 83  227540.0  227540.0  227540.0  227533.0   NaN   NaN
#
# [1 rows x 64 columns]

# %%
df6 = df6.melt(id_vars=['Country Name'],var_name='Year',value_name='Land area (sq. km)')

# %%
df6.head(5)
# Out:
#   Country Name  Year  Land area (sq. km)
# 0        Ghana  1960                 NaN
# 1        Ghana  1961            227540.0
# 2        Ghana  1962            227540.0
# 3        Ghana  1963            227540.0
# 4        Ghana  1964            227540.0

# %%
df6.rename(columns={'Country Name':'Country'}, inplace=True)

# %%
# Merge df1 and df2 on 'Country' and 'Year'
merged_df = pd.merge(df1, df2, on=['Country', 'Year'])

# Merge merged_df and df3 on 'Country' and 'Year'
merged_df = pd.merge(merged_df, df3, on=['Country', 'Year'])

# Merge merged_df and df4 on 'Country' and 'Year'
merged_df = pd.merge(merged_df, df4, on=['Country', 'Year'])

# Merge merged_df and df5 on 'Country' and 'Year'
merged_df = pd.merge(merged_df, df5, on=['Country', 'Year'])



# Print the merged DataFrame
print(merged_df)
# Out:
#    Country  Year  Agricultural irrigated land (% of total agriculture)  \
# 0    Ghana  1960                                                NaN
# 1    Ghana  1961                                                NaN
# 2    Ghana  1962                                                NaN
# 3    Ghana  1963                                                NaN
# 4    Ghana  1964                                                NaN
# ..     ...   ...                                                ...
# 58   Ghana  2018                                                NaN
# 59   Ghana  2019                                                NaN
# 60   Ghana  2020                                                NaN
# 61   Ghana  2021                                                NaN
# 62   Ghana  2022                                                NaN
#
#     Agricultural land (% of land area)  Agricultural land (sq. km)  \
# 0                                  NaN                         NaN
# ...

# %%
# Merge merged_df and df6 on 'Country' and 'Year'
merged_df = pd.merge(merged_df, df6, on=['Country','Year'])

# %%
merged_df
# Out:
#    Country  Year  Agricultural irrigated land (% of total agriculture)  \
# 0    Ghana  1960                                                NaN
# 1    Ghana  1961                                                NaN
# 2    Ghana  1962                                                NaN
# 3    Ghana  1963                                                NaN
# 4    Ghana  1964                                                NaN
# ..     ...   ...                                                ...
# 58   Ghana  2018                                                NaN
# 59   Ghana  2019                                                NaN
# 60   Ghana  2020                                                NaN
# 61   Ghana  2021                                                NaN
# 62   Ghana  2022                                                NaN
#
#     Agricultural land (% of land area)  Agricultural land (sq. km)  \
# 0                                  NaN                         NaN
# ...

# %%
merged_df.dtypes
# Out:
# Country                                                  object
# Year                                                     object
# Agricultural irrigated land (% of total agriculture)    float64
# Agricultural land (% of land area)                      float64
# Agricultural land (sq. km)                              float64
# Arable land (% of land area)                            float64
# Arable land (hectares per person)                       float64
# Land area (sq. km)                                      float64
# dtype: object

# %%
merged_df['Year'] = merged_df['Year'].astype('int64')

# %%
merged_df.dtypes
# Out:
# Country                                                  object
# Year                                                      int64
# Agricultural irrigated land (% of total agriculture)    float64
# Agricultural land (% of land area)                      float64
# Agricultural land (sq. km)                              float64
# Arable land (% of land area)                            float64
# Arable land (hectares per person)                       float64
# Land area (sq. km)                                      float64
# dtype: object

# %%
# Read Forest data profile
file_path = r"C:\Users\chimi\Desktop\Python Data Science Projects\Cocoa Production\Data Collection\Forest Area(%Land Area.csv"
data = pd.read_csv(file_path)

# Now you can work with the data
# For example, you can print the first few rows
print(data.head())
# Out:
#    Year  Forest area (% of land area)
# 0  1990                         43.62
# 1  1991                         43.14
# 2  1992                         42.67
# 3  1993                         42.20
# 4  1994                         41.72

# %%
data.dtypes
# Out:
# Year                              int64
# Forest area (% of land area)    float64
# dtype: object

# %%
# Merge the datasets on 'Year'
final_df = pd.merge(merged_df, data, on='Year')

# %%
final_df.head(5)
# Out:
#   Country  Year  Agricultural irrigated land (% of total agriculture)  \
# 0   Ghana  1990                                                NaN
# 1   Ghana  1991                                                NaN
# 2   Ghana  1992                                                NaN
# 3   Ghana  1993                                                NaN
# 4   Ghana  1994                                                NaN
#
#    Agricultural land (% of land area)  Agricultural land (sq. km)  \
# 0                           55.396853                    126050.0
# 1                           55.902259                    127200.0
# 2                           55.902259                    127200.0
# 3                           56.253845                    128000.0
# 4                           56.693329                    129000.0
#
#    Arable land (% of land area)  Arable land (hectares per person)  \
# 0                     11.866046                           0.174791
# ...

# %%
final_df.to_csv('land_use.csv',index=False)
